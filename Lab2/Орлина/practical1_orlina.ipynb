# %% [markdown]
# ## Practical 1: word2vec
# <p>Oxford CS - Deep NLP 2017<br>
# https://www.cs.ox.ac.uk/teaching/courses/2016-2017/dl/</p>
# <p>[Yannis Assael, Brendan Shillingford, Chris Dyer]</p>

# %% [markdown]
# This practical is presented as an IPython Notebook, with the code written for recent versions of **Python 3**. The code in this practical will not work with Python 2 unless you modify it. If you are using your own Python installation, ensure you have a setup identical to that described in the installation shell script (which is intended for use with the department lab machines). We will be unable to support installation on personal machines due to time constraints, so please use the lab machines and the setup script if you are unfamiliar with how to install Anaconda.
#
# To execute a notebook cell, press `shift-enter`. The return value of the last command will be displayed, if it is not `None`.
#
# Potentially useful library documentation, references, and resources:
#
# * IPython notebooks: <https://ipython.org/ipython-doc/3/notebook/notebook.html#introduction>
# * Numpy numerical array library: <https://docs.scipy.org/doc/>
# * Gensim's word2vec: <https://radimrehurek.com/gensim/models/word2vec.html>
# * Bokeh interactive plots: <http://bokeh.pydata.org/en/latest/> (we provide plotting code here, but click the thumbnails for more examples to copy-paste)
# * scikit-learn ML library (aka `sklearn`): <http://scikit-learn.org/stable/documentation.html>
# * nltk NLP toolkit: <http://www.nltk.org/>
# * tutorial for processing xml in python using `lxml`: <http://lxml.de/tutorial.html> (we did this for you below, but in case you need it in the future)

# %%
import numpy as np
import os
from random import shuffle
import re

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4a0dabf8-fccf-4fc0-835b-cb1d74c5fc51">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Part 0: Download the TED dataset

# %%
import urllib.request
import zipfile
import lxml.etree

# %%
# Download the dataset if it's not already there: this may take a minute as it is 75MB
if not os.path.isfile('ted_en.zip'):
    urllib.request.urlretrieve("https://wit3.fbk.eu/get.php?path=XML_releases/xml/ted_en-20160408.zip&filename=ted_en-20160408.zip", filename="ted_en-20160408.zip")

# %%
# For now, we're only interested in the subtitle text, so let's extract that from the XML:
with zipfile.ZipFile('ted_en.zip', 'r') as z:
    doc = lxml.etree.parse(z.open('ted_en-20160408.xml', 'r'))
input_text = '\n'.join(doc.xpath('//content/text()'))
del doc

# %% [markdown]
# ### Part 1: Preprocessing
#
# In this part, we attempt to clean up the raw subtitles a bit, so that we get only sentences. The following substring shows examples of what we're trying to get rid of. Since it's hard to define precisely what we want to get rid of, we'll just use some simple heuristics.

# %%
i = input_text.find("Hyowon Gweon: See this?")
input_text[i-20:i+150]
# Out:
# ' baby does.\n(Video) Hyowon Gweon: See this? (Ball squeaks) Did you see that? (Ball squeaks) Cool. See this one? (Ball squeaks) Wow.\nLaura Schulz: Told you. (Laughs)\n(Vide'

# %% [markdown]
# Let's start by removing all parenthesized strings using a regex:

# %%
input_text_noparens = re.sub(r'\([^)]*\)', '', input_text)

# %% [markdown]
# We can verify the same location in the text is now clean as follows. We won't worry about the irregular spaces since we'll later split the text into sentences and tokenize it anyway.

# %%
i = input_text_noparens.find("Hyowon Gweon: See this?")
input_text_noparens[i-20:i+150]
# Out:
# "hat the baby does.\n Hyowon Gweon: See this?  Did you see that?  Cool. See this one?  Wow.\nLaura Schulz: Told you. \n HG: See this one?  Hey Clara, this one's for you. You "

# %% [markdown]
# Now, let's attempt to remove speakers' names that occur at the beginning of a line, by deleting pieces of the form "`<up to 20 characters>:`", as shown in this example. Of course, this is an imperfect heuristic.

# %%
sentences_strings_ted = []
for line in input_text_noparens.split('\n'):
    m = re.match(r'^(?:(?P<precolon>[^:]{,20}):)?(?P<postcolon>.*)$', line)
    sentences_strings_ted.extend(sent for sent in m.groupdict()['postcolon'].split('.') if sent)

# Uncomment if you need to save some RAM: these strings are about 50MB.
# del input_text, input_text_noparens

# Let's view the first few:
sentences_strings_ted[:5]
# Out:
# ["Here are two reasons companies fail: they only do more of the same, or they only do what's new",
#  'To me the real, real solution to quality growth is figuring out the balance between two activities: exploration and exploitation',
#  ' Both are necessary, but it can be too much of a good thing',
#  'Consider Facit',
#  " I'm actually old enough to remember them"]

# %% [markdown]
# Now that we have sentences, we're ready to tokenize each of them into words. This tokenization is imperfect, of course. For instance, how many tokens is "can't", and where/how do we split it? We'll take the simplest naive approach of splitting on spaces. Before splitting, we remove non-alphanumeric characters, such as punctuation. You may want to consider the following question: why do we replace these characters with spaces rather than deleting them? Think of a case where this yields a different answer.

# %%
sentences_ted = []
for sent_str in sentences_strings_ted:
    tokens = re.sub(r"[^a-z0-9]+", " ", sent_str.lower()).split()
    sentences_ted.append(tokens)

# %% [markdown]
# Two sample processed sentences:

# %%
len(sentences_ted)
# Out:
# 266694

# %%
print(sentences_ted[0])
print(sentences_ted[1])
# Out:
# ['here', 'are', 'two', 'reasons', 'companies', 'fail', 'they', 'only', 'do', 'more', 'of', 'the', 'same', 'or', 'they', 'only', 'do', 'what', 's', 'new']
# ['to', 'me', 'the', 'real', 'real', 'solution', 'to', 'quality', 'growth', 'is', 'figuring', 'out', 'the', 'balance', 'between', 'two', 'activities', 'exploration', 'and', 'exploitation']

# %% [markdown]
# ### Part 2: Word Frequencies

# %% [markdown]
# If you store the counts of the top 1000 words in a list called `counts_ted_top1000`, the code below will plot the histogram requested in the writeup.

# %%
counts = {}
for sentence in sentences_ted:
    for word in sentence:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

# %%
words_top_ted = sorted(counts, reverse=True, key=counts.__getitem__)
counts_ted_top1000 = [counts[word] for word in words_top_ted[:1000]]

# %% [markdown]
# Plot distribution of top-1000 words

# %%
hist, edges = np.histogram(counts_ted_top1000, density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Top-1000 words distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="49473313-4629-4421-b2fb-18b8e7cb5cfc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("49473313-4629-4421-b2fb-18b8e7cb5cfc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("49473313-4629-4421-b2fb-18b8e7cb5cfc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '49473313-4629-4421-b2fb-18b8e7cb5cfc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4604673c-4f48-4198-8c8c-628bd89b4870":{"roots":{"references":[{"attributes":{"plot":{"id":"e7c70b95-40ff-4c50-af47-f8fb3d9e7c56","subtype":"Figure","type":"Plot"}},"id":"97764a9c-173a-4627-ac0c-e3a55582ab6f","type":"ResetTool"},{"attributes":{"plot":{"id":"e7c70b95-40ff-4c50-af47-f8fb3d9e7c56","subtype":"Figure","type":"Plot"}},"id":"38a72869-89e6-451d-86b0-9d5a5e70b076","type":"SaveTool"},{"attributes":{},"id":"854efffd-1dbb-4dcb-bce3-adaf4bd2f388","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"c06d7d9b-e9c4-46d6-9da6-72868d5b81a0","type":"ColumnDataSource"},"glyph":{"id":"f064940f-1922-4db3-8cc3-052fb48218c7","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"0f045060-9391-4ba6-a6a6-5005b0f760b2","type":"Quad"},"selection_glyph":null},"id":"22ec7d43-1dda-4382-a16e-381b8615af16","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"Top-1000 words distribution"},"id":"a9f55fde-206d-4731-a680-d966f812dbd6","type":"Title"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"c06d7d9b-e9c4-46d6-9da6-72868d5b81a0","type":"ColumnDataSource"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_color":{"value":"#555555"},"right":{"field":"right"},"top":{"field":"top"}},"id":"f064940f-1922-4db3-8cc3-052fb48218c7","type":"Quad"},{"attributes":{"callback":null},"id":"6d15c615-c5eb-468e-ae9b-1caf98ed3695","type":"DataRange1d"},{"attributes":{},"id":"9b0b6571-dd76-4a77-b0dd-99ae992550a1","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2837a8a4-85f6-4b28-b59c-4f06318724ff","type":"PanTool"},{"id":"bd4d571a-308e-45d7-9ae4-3c0976f4277f","type":"WheelZoomTool"},{"id":"97764a9c-173a-4627-ac0c-e3a55582ab6f","type":"ResetTool"},{"id":"38a72869-89e6-451d-86b0-9d5a5e70b076","type":"SaveTool"}]},"id":"23c4bc00-0277-4a9f-bf04-45f6d7ddd1ae","type":"Toolbar"},{"attributes":{"below":[{"id":"7ecd7773-2657-4321-8ce1-44527c2ab5e0","type":"LinearAxis"}],"left":[{"id":"f88756cf-f4a1-41e1-8fd4-ca7eb6ea9575","type":"LinearAxis"}],"renderers":[{"id":"7ecd7773-2657-4321-8ce1-44527c2ab5e0","type":"LinearAxis"},{"id":"ccfcb008-53dd-4cdf-8a76-55a0c7faf68a","type":"Grid"},{"id":"f88756cf-f4a1-41e1-8fd4-ca7eb6ea9575","type":"LinearAxis"},{"id":"9c215f32-2f9a-446c-aba7-5c4f14283809","type":"Grid"},{"id":"22ec7d43-1dda-4382-a16e-381b8615af16","type":"GlyphRenderer"}],"title":{"id":"a9f55fde-206d-4731-a680-d966f812dbd6","type":"Title"},"tool_events":{"id":"9b0b6571-dd76-4a77-b0dd-99ae992550a1","type":"ToolEvents"},"toolbar":{"id":"23c4bc00-0277-4a9f-bf04-45f6d7ddd1ae","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"6d15c615-c5eb-468e-ae9b-1caf98ed3695","type":"DataRange1d"},"y_range":{"id":"a8418289-8981-4e16-9f94-1cffaf74f6a2","type":"DataRange1d"}},"id":"e7c70b95-40ff-4c50-af47-f8fb3d9e7c56","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"854efffd-1dbb-4dcb-bce3-adaf4bd2f388","type":"BasicTickFormatter"},"plot":{"id":"e7c70b95-40ff-4c50-af47-f8fb3d9e7c56","subtype":"Figure","type":"Plot"},"ticker":{"id":"fef9e8e7-ab6c-40b8-b011-cdf7ee67baca","type":"BasicTicker"}},"id":"7ecd7773-2657-4321-8ce1-44527c2ab5e0","type":"LinearAxis"},{"attributes":{"callback":null},"id":"a8418289-8981-4e16-9f94-1cffaf74f6a2","type":"DataRange1d"},{"attributes":{},"id":"fef9e8e7-ab6c-40b8-b011-cdf7ee67baca","type":"BasicTicker"},{"attributes":{"plot":{"id":"e7c70b95-40ff-4c50-af47-f8fb3d9e7c56","subtype":"Figure","type":"Plot"},"ticker":{"id":"fef9e8e7-ab6c-40b8-b011-cdf7ee67baca","type":"BasicTicker"}},"id":"ccfcb008-53dd-4cdf-8a76-55a0c7faf68a","type":"Grid"},{"attributes":{"formatter":{"id":"30bda6da-de44-4384-aca9-b2bd586fb91f","type":"BasicTickFormatter"},"plot":{"i ...

# %% [markdown]
# ### Part 3: Train Word2Vec

# %%
import gensim
# Out:
# Using TensorFlow backend.

# %%
model_ted = gensim.models.Word2Vec(size=100, min_count=8, workers=4)
model_ted.build_vocab(sentences_ted)
model_ted.train(sentences_ted, total_examples=model_ted.corpus_count, epochs=30)
model_ted.save('/tmp/w2v_model_ted')

# %% [markdown]
# ### Part 4: Ted Learnt Representations

# %% [markdown]
# Finding similar words: (see gensim docs for more functionality of `most_similar`)

# %%
model_ted.most_similar("man")
# Out:
# [('woman', 0.8055257797241211),
#  ('guy', 0.737199068069458),
#  ('gentleman', 0.7055171728134155),
#  ('soldier', 0.6886089444160461),
#  ('rabbi', 0.6572558283805847),
#  ('boy', 0.6525644063949585),
#  ('lady', 0.6377718448638916),
#  ('girl', 0.6368485689163208),
#  ('pianist', 0.6364774107933044),
#  ('person', 0.6300219893455505)]

# %%
model_ted.most_similar("computer")
# Out:
# [('software', 0.6675026416778564),
#  ('computers', 0.6280431747436523),
#  ('machine', 0.6089670658111572),
#  ('algorithm', 0.6083300113677979),
#  ('simulation', 0.5925795435905457),
#  ('interface', 0.5869885683059692),
#  ('device', 0.5850368738174438),
#  ('smartphone', 0.5825691223144531),
#  ('iphone', 0.5680442452430725),
#  ('browser', 0.5680277347564697)]

# %%
model_ted.most_similar(positive=['cow', 'milk'], negative=['bird'])
# Out:
# [('underwear', 0.5230211615562439),
#  ('sugar', 0.5226045250892639),
#  ('cooks', 0.513624906539917),
#  ('clothes', 0.4970288574695587),
#  ('parents', 0.4889562726020813),
#  ('meal', 0.48813945055007935),
#  ('pants', 0.4850703477859497),
#  ('chicken', 0.48325115442276),
#  ('drink', 0.47970789670944214),
#  ('fat', 0.47692662477493286)]

# %% [markdown]
# #### t-SNE visualization
# To use the t-SNE code below, first put a list of the top 1000 words (as strings) into a variable `words_top_ted`. The following code gets the corresponding vectors from the model, assuming it's called `model_ted`:

# %%
# This assumes words_top_ted is a list of strings, the top 1000 words
words_top_vec_ted = model_ted[words_top_ted[:1000]]

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(words_top_vec_ted)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_top_ted[:1000]))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
# /Users/arshinovgrigoriy/anaconda/lib/python3.6/site-packages/bokeh/models/sources.py:81: BokehUserWarning: ColumnDataSource's columns must be of the same length
#   lambda: warnings.warn("ColumnDataSource's columns must be of the same length", BokehUserWarning))
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a79b8f5e-cd29-4cbe-8ddc-c676cb9c9fcf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a79b8f5e-cd29-4cbe-8ddc-c676cb9c9fcf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a79b8f5e-cd29-4cbe-8ddc-c676cb9c9fcf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a79b8f5e-cd29-4cbe-8ddc-c676cb9c9fcf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d0db9915-d3f3-4c1d-888a-3645fdbce7bc":{"roots":{"references":[{"attributes":{},"id":"ab1af526-b706-402c-9af9-c31303c8beb1","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"70a3e562-d0ab-4150-8145-7b0eb78c39bd","type":"BasicTickFormatter"},"plot":{"id":"98725478-819b-48db-9dd5-a07c71fb5a10","subtype":"Figure","type":"Plot"},"ticker":{"id":"9fc52ad0-9719-41f8-8458-16e04fc90f3c","type":"BasicTicker"}},"id":"77253db3-e214-42e1-9644-04f3f019751a","type":"LinearAxis"},{"attributes":{"formatter":{"id":"ab1af526-b706-402c-9af9-c31303c8beb1","type":"BasicTickFormatter"},"plot":{"id":"98725478-819b-48db-9dd5-a07c71fb5a10","subtype":"Figure","type":"Plot"},"ticker":{"id":"4e30f809-427c-4117-8c8e-cff48b51a8aa","type":"BasicTicker"}},"id":"7890c7e0-b861-4565-9412-fa9638900665","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":8},"x":{"field":"x1"},"y":{"field":"x2"}},"id":"2bf2f527-d8be-4c77-a76c-713b3b31ee55","type":"Circle"},{"attributes":{},"id":"952ba418-58fb-4e9d-b48a-e819f1948519","type":"ToolEvents"},{"attributes":{},"id":"4e30f809-427c-4117-8c8e-cff48b51a8aa","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x1","x2","names"],"data":{"names":["the","and","to","of","a","that","i","in","it","you","we","is","s","this","so","they","was","for","are","have","but","what","on","with","can","t","about","there","be","as","at","all","not","do","my","one","re","people","like","if","from","now","our","he","an","just","these","or","when","because","very","me","out","by","them","how","know","up","going","had","more","think","who","were","see","your","their","which","would","here","really","get","ve","then","m","world","us","time","some","has","don","actually","into","way","where","will","years","things","other","no","could","go","well","want","been","make","right","she","said","something","those","first","two","than","much","also","look","new","thing","little","got","back","over","most","say","even","his","life","only","work","many","take","need","did","lot","kind","why","good","around","every","different","down","ll","let","her","through","same","being","come","d","day","year","three","use","doing","put","called","any","today","percent","made","after","thank","tell","great","human","find","didn","fact","talk","change","started","another","idea","big","last","own","before","its","never","should","better","give","thought","went","might","important","000","again","able","together","still","problem","off","next","part","course","system","him","does","each","start","show","long","ago","story","came","brain","few","bit","between","used","place","technology","women","too","old","mean","data","water","looking","question","maybe","found","love","doesn","end","example","10","done","point","four","real","wanted","ever","school","understand","sort","live","call","whole","children","always","trying","may","person","away","believe","feel","try","million","working","help","everything","five","country","thinking","second","using","information","money","means","power","took","times","high","space","number","kids","home","become","create","small","design","making","best","left","getting","future","enough","man","quite","city","without","sense","happened","comes","social","probably","less","light","talking","energy","am","building","science","food","body","told","interesting","ask","half","pretty","hard","play","anything","lives","countries","coming","such","family","stuff","dollars","earth","moment","20","imagine","across","side","while","saw","happen","once","okay","build","having","men","later","experience","makes","asked","living","seen","says","room","hand","simple","health","ways","else","case","yet","almost","young","days","nothing","care","bad","happens","goes","move","states","reason","computer","open","learn","africa","process","inside","someone","six","f ...

# %% [markdown]
# ### Part 5: Wiki Learnt Representations

# %% [markdown]
# Download dataset

# %%
if not os.path.isfile('wikitext.zip'):
    urllib.request.urlretrieve("https://s3.amazonaws.com/research.metamind.io/wikitext/wikitext-103-raw-v1.zip", filename="wikitext-103-raw-v1.zip")

# %%
with zipfile.ZipFile('wikitext.zip', 'r') as z:
    input_text = str(z.open('wikitext-103-raw/wiki.train.raw', 'r').read(), encoding='utf-8') # Thanks Robert Bastian

# %% [markdown]
# Preprocess sentences (note that it's important to remove small sentences for performance)

# %%
sentences_wiki = []
for line in input_text.split('\n'):
    s = [x for x in line.split('.') if x and len(x.split()) >= 5]
    sentences_wiki.extend(s)
    
for s_i in range(len(sentences_wiki)):
    sentences_wiki[s_i] = re.sub("[^a-z]", " ", sentences_wiki[s_i].lower())
    sentences_wiki[s_i] = re.sub(r'\([^)]*\)', '', sentences_wiki[s_i])
del input_text

# %%
# sample 1/5 of the data
shuffle(sentences_wiki)
print(len(sentences_wiki))
sentences_wiki = sentences_wiki[:int(len(sentences_wiki)/5)]
print(len(sentences_wiki))
sentences_wiki = [sentence.split() for sentence in sentences_wiki]
# Out:
# 4267112
# 853422

# %% [markdown]
# Now, repeat all the same steps that you performed above. You should be able to reuse essentially all the code.

# %%
counts_wiki = {}
for sentence in sentences_wiki:
    for word in sentence:
        if word in counts_wiki:
            counts_wiki[word] += 1
        else:
            counts_wiki[word] = 1

# %%
words_top_wiki = sorted(counts_wiki, reverse=True, key=counts_wiki.__getitem__)
counts_wiki_top1000 = [counts_wiki[word] for word in words_top_wiki[:1000]]

# %% [markdown]
# Plot distribution of top-1000 words

# %%
hist, edges = np.histogram(counts_wiki_top1000, density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Top-1000 words distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f4770b80-a1f3-49b8-b14b-508f761e7c18"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f4770b80-a1f3-49b8-b14b-508f761e7c18").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f4770b80-a1f3-49b8-b14b-508f761e7c18");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f4770b80-a1f3-49b8-b14b-508f761e7c18' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"52d62b48-cf46-4474-828c-f851ae5b473d":{"roots":{"references":[{"attributes":{},"id":"88c9073d-631a-4324-8073-ff787a1cb764","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Top-1000 words distribution"},"id":"a09ec4e5-14c7-46c5-83fa-6952a0f4a052","type":"Title"},{"attributes":{"data_source":{"id":"41f38ef6-5016-4f1f-aa6c-ac2be8d11394","type":"ColumnDataSource"},"glyph":{"id":"80cbcc7b-ddf7-449d-b855-d7371eb9f9ca","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"03e7bbe2-5d5d-461f-8c40-af5c839bf0d8","type":"Quad"},"selection_glyph":null},"id":"09e9ce97-15c7-4186-bb6d-5b10933b7661","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"be9a07d6-fdd3-4398-ae7a-fb5b4e0f89fd","type":"DataRange1d"},{"attributes":{},"id":"cbed428f-41d7-47e0-87b6-02a0575cbf68","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ca5acf0e-3394-4772-be87-2506b587d920","type":"PanTool"},{"id":"7936093b-6c77-45ee-9eb1-6fab3858f7f8","type":"WheelZoomTool"},{"id":"c75e0da0-eb71-4fe3-878d-93a0bc910635","type":"ResetTool"},{"id":"aeb7d554-466d-47d8-9930-412337e12210","type":"SaveTool"}]},"id":"b6f97363-48ee-419b-8fd7-8f4a2d5c3744","type":"Toolbar"},{"attributes":{"formatter":{"id":"88c9073d-631a-4324-8073-ff787a1cb764","type":"BasicTickFormatter"},"plot":{"id":"f3761ed6-7d46-4d0b-91a1-cb9b35b3c986","subtype":"Figure","type":"Plot"},"ticker":{"id":"4a1dbd59-71c2-4aa3-b68d-d7ca388fe100","type":"BasicTicker"}},"id":"7dc0148a-d603-4df2-a424-ef0705f6a5fb","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["left","right","top"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[100]},"right":{"__ndarray__":"...","dtype":"float64","shape":[100]},"top":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"41f38ef6-5016-4f1f-aa6c-ac2be8d11394","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"2fcecd29-01fe-4590-a440-7b0adda4630c","type":"DataRange1d"},{"attributes":{},"id":"4a1dbd59-71c2-4aa3-b68d-d7ca388fe100","type":"BasicTicker"},{"attributes":{"plot":{"id":"f3761ed6-7d46-4d0b-91a1-cb9b35b3c986","subtype":"Figure","type":"Plot"},"ticker":{"id":"4a1dbd59-71c2-4aa3-b68d-d7ca388fe100","type":"BasicTicker"}},"id":"de5e20df-8468-40ca-81ff-d5308fd6bb7f","type":"Grid"},{"attributes":{"formatter":{"id":"ce393e30-7255-4dc0-9dfb-0ddc9cbef91d","type":"BasicTickFormatter"},"plot":{"id":"f3761ed6-7d46-4d0b-91a1-cb9b35b3c986","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f4f5c9f-1b99-485a-a97f-d494b747f0ad","type":"BasicTicker"}},"id":"66fea567-ae8c-4524-b50d-ae2578b209a7","type":"LinearAxis"},{"attributes":{},"id":"0f4f5c9f-1b99-485a-a97f-d494b747f0ad","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"f3761ed6-7d46-4d0b-91a1-cb9b35b3c986","subtype":"Figure","type":"Plot"},"ticker":{"id":"0f4f5c9f-1b99-485a-a97f-d494b747f0ad","type":"BasicTicker"}},"id":"5c2ed232-ed7d-4895-985b-994fddae921c","type":"Grid"},{"attributes":{"plot":{"id":"f3761ed6-7d46-4d0b-91a1-cb9b35b3c986","subtype":"Figure","type":"Plot"}},"id":"ca5acf0e-3394-4772-be87-2506b587d920","type":"PanTool"},{"attributes":{"below":[{"id":"7dc0148a-d603-4df2-a424-ef0705f6a5fb","type":"LinearAxis"}],"left":[{"id":"66fea567-ae8c-4524-b50d-ae2578b209a7","type":"LinearAxis"}],"renderers":[{"id":"7dc0148a-d603-4df2-a424-ef0705f6a5fb","type":"LinearAxis"},{"id":"de5e20df-8468-40ca-81ff-d5308fd6bb7f","type":"Grid"},{"id":"66fea567-ae8c-4524-b50d-ae2578b209a7","type":"LinearAxis"},{"id":"5c2ed232-ed7d-4895-985b-994fddae921c","type":"Grid"},{"id":"09e9ce97-15c7-4186-bb6d-5b10933b7661","type":"GlyphRenderer"}],"title":{"id":"a09ec4e5-14c7-46c5-83fa-6952a0f4a052","type":"Title"},"tool_events":{"id":"cbed428f-41d7-47e0-87b6-02a0575cbf68","type":"ToolEvents"},"toolbar":{"id":"b6f97363-48ee-419b-8fd7-8f4a2d5c3744","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"be9a07d6-fdd3-4398-ae7a-fb5b4e0f89fd","type":"DataRange1d"},"y_ra ...

# %% [markdown]
# ### Train Word2Vec

# %%
model_wiki = gensim.models.Word2Vec(size=100, min_count=10, workers=4)
model_wiki.build_vocab(sentences_wiki)
model_wiki.train(sentences_wiki, total_examples=model_wiki.corpus_count, epochs=15)
model_wiki.save('w2v_model_wiki')

# %% [markdown]
# ### Part 4: Wiki Learnt Representations

# %% [markdown]
# Finding similar words: (see gensim docs for more functionality of `most_similar`)

# %%
model_wiki.most_similar("man")
# Out:
# [('woman', 0.7462983131408691),
#  ('boy', 0.6671868562698364),
#  ('person', 0.6359971761703491),
#  ('girl', 0.6263032555580139),
#  ('soldier', 0.5588923692703247),
#  ('kid', 0.5443299412727356),
#  ('teenager', 0.5335559844970703),
#  ('sailor', 0.5315560102462769),
#  ('creature', 0.5269191265106201),
#  ('dog', 0.5143892765045166)]

# %%
model_wiki.most_similar("computer")
# Out:
# [('software', 0.7748256921768188),
#  ('computers', 0.7204856872558594),
#  ('hardware', 0.6724118590354919),
#  ('interface', 0.6693423986434937),
#  ('handheld', 0.655257523059845),
#  ('user', 0.6454858779907227),
#  ('technology', 0.6390522718429565),
#  ('mainframe', 0.6291611194610596),
#  ('desktop', 0.6250385642051697),
#  ('cgi', 0.623268723487854)]

# %%
model_wiki.most_similar(positive=['cow', 'milk'], negative=['bird'])
# Out:
# [('parsley', 0.6669273972511292),
#  ('butter', 0.6442516446113586),
#  ('yogurt', 0.6404125690460205),
#  ('mustard', 0.6302924156188965),
#  ('vinegar', 0.6280786395072937),
#  ('bottles', 0.6277163028717041),
#  ('starch', 0.6253898739814758),
#  ('beans', 0.6224865913391113),
#  ('wine', 0.6189248561859131),
#  ('juice', 0.6174142956733704)]

# %% [markdown]
# #### t-SNE visualization

# %%
# This assumes words_top_wiki is a list of strings, the top 1000 words
words_top_vec_wiki = model_wiki[words_top_wiki[:1000]]
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_wiki_tsne = tsne.fit_transform(words_top_vec_wiki)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="word2vec T-SNE for most common words")

source = ColumnDataSource(data=dict(x1=words_top_wiki_tsne[:,0],
                                    x2=words_top_wiki_tsne[:,1],
                                    names=words_top_wiki[:1000]))

p.scatter(x="x1", y="x2", size=8, source=source)

labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(labels)

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7a39c8d1-7487-4a84-8be8-fec3c1827cdd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7a39c8d1-7487-4a84-8be8-fec3c1827cdd").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7a39c8d1-7487-4a84-8be8-fec3c1827cdd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7a39c8d1-7487-4a84-8be8-fec3c1827cdd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ec4bdc42-38b2-4a6f-be0c-6b8b2a2e05b7":{"roots":{"references":[{"attributes":{"callback":null},"id":"35f110c6-c637-495b-ae5b-b3cdfd935d16","type":"DataRange1d"},{"attributes":{"plot":{"id":"28949c18-8d39-4a47-a7e2-a8ca8788c3ab","subtype":"Figure","type":"Plot"},"source":{"id":"4fe25fa6-d37b-489f-8ec8-6ea28cb4d618","type":"ColumnDataSource"},"text":{"field":"names"},"text_align":"center","text_color":{"value":"#555555"},"text_font_size":{"value":"8pt"},"x":{"field":"x1"},"y":{"field":"x2"},"y_offset":{"value":6}},"id":"749fe48d-ff44-43ef-b1ac-e74cfc886f63","type":"LabelSet"},{"attributes":{"below":[{"id":"3a20d553-6d87-4df9-ac19-e50925e0e81c","type":"LinearAxis"}],"left":[{"id":"2216e0c9-2f48-41fe-abe6-6b7e806e44ec","type":"LinearAxis"}],"renderers":[{"id":"3a20d553-6d87-4df9-ac19-e50925e0e81c","type":"LinearAxis"},{"id":"d87e20b5-d5e0-4b39-ae21-2a64329427da","type":"Grid"},{"id":"2216e0c9-2f48-41fe-abe6-6b7e806e44ec","type":"LinearAxis"},{"id":"c6881ea8-afde-4003-9785-65d87cfd7f57","type":"Grid"},{"id":"8e9e86b5-2f08-4150-b218-ba027e84d46c","type":"GlyphRenderer"},{"id":"749fe48d-ff44-43ef-b1ac-e74cfc886f63","type":"LabelSet"}],"title":{"id":"f8688730-c9d9-4d5e-943e-fa52222df4b3","type":"Title"},"tool_events":{"id":"3cb0748b-d71c-4bcf-9a02-ebac6798c040","type":"ToolEvents"},"toolbar":{"id":"328cd0d7-932f-4e7b-9d69-0d226858eed4","type":"Toolbar"},"toolbar_location":"above","x_range":{"id":"35f110c6-c637-495b-ae5b-b3cdfd935d16","type":"DataRange1d"},"y_range":{"id":"2335855f-0dce-4284-b32e-ad20ee4b95f4","type":"DataRange1d"}},"id":"28949c18-8d39-4a47-a7e2-a8ca8788c3ab","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x1","x2","names"],"data":{"names":["the","of","and","in","to","a","was","s","on","as","for","that","with","by","is","his","at","he","it","from","were","an","had","which","be","this","but","are","first","not","their","after","one","her","also","its","they","two","or","have","who","new","been","has","she","when","during","time","other","would","into","all","i","more","while","over","him","game","later","only","up","most","about","three","between","out","th","than","there","film","some","may","year","before","made","such","no","second","season","where","war","world","years","both","however","song","then","used","being","these","through","them","series","against","m","many","album","became","north","number","city","can","well","team","four","part","including","several","united","under","early","state","music","day","south","so","episode","following","states","said","known","although","american","did","work","could","began","until","like","released","t","because","called","high","people","end","since","around","british","each","if","long","life","found","september","national","same","west","best","back","us","five","million","another","along","km","you","area","took","show","use","century","august","any","final","group","off","received","school","october","due","will","john","what","east","line","june","system","government","march","july","games","home","single","november","april","third","much","general","down","large","major","based","set","york","left","family","house","history","place","january","company","army","just","played","we","road","character","king","included","december","now","band","name","six","wrote","main","won","near","times","own","according","d","st","within","led","those","video","described","men","river","de","next","late","battle","last","make","release","named","way","record","original","death","still","air","league","very","man","top","route","species","storm","ship","old","force","club","even","small","great","u","february","production","though","days","again","public","built","held","role","members","story","further","book","among","play","service","power","b","university","side","do","german","french","match","white","often","player","having","continued","point","division","career","h","water","order","town","former","black","local ...
